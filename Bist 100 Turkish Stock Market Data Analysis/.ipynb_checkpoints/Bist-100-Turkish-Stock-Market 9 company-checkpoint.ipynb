# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np
# %matplotlib inline

# %%
eczacibasi = pd.read_csv('D:/G-PYTHON/Python 42/Data science/Data Science Projects/Bist 100 Turkish Stock Market Data Analysis/Dataset/eczacibasi.csv')
aselsan = pd.read_csv('D:/G-PYTHON/Python 42/Data science/Data Science Projects/Bist 100 Turkish Stock Market Data Analysis/Dataset/aselsan.csv')
bimas = pd.read_csv('D:/G-PYTHON/Python 42/Data science/Data Science Projects/Bist 100 Turkish Stock Market Data Analysis/Dataset/bimas.csv')
ulker = pd.read_csv('D:/G-PYTHON/Python 42/Data science/Data Science Projects/Bist 100 Turkish Stock Market Data Analysis/Dataset/ulker.csv')
vestel = pd.read_csv('D:/G-PYTHON/Python 42/Data science/Data Science Projects/Bist 100 Turkish Stock Market Data Analysis/Dataset/vestel.csv')
enerjisa = pd.read_csv('D:/G-PYTHON/Python 42/Data science/Data Science Projects/Bist 100 Turkish Stock Market Data Analysis/Dataset/enerjisa.csv')
ford = pd.read_csv('D:/G-PYTHON/Python 42/Data science/Data Science Projects/Bist 100 Turkish Stock Market Data Analysis/Dataset/ford-otosan.csv')
ttelekom = pd.read_csv('D:/G-PYTHON/Python 42/Data science/Data Science Projects/Bist 100 Turkish Stock Market Data Analysis/Dataset/ttelekom.csv')
karsan = pd.read_csv('D:/G-PYTHON/Python 42/Data science/Data Science Projects/Bist 100 Turkish Stock Market Data Analysis/Dataset/karsan.csv')

# %%
eczacibasi.head()
# Out:
#          Date  adjclose   low  high        volume  open
# 0  2020-05-29      5.62  5.58  5.71  1.117549e+08  5.61
# 1  2020-05-28      5.61  5.59  5.80  1.232425e+08  5.71
# 2  2020-05-27      5.71  5.70  5.95  2.516636e+08  5.70
# 3  2020-05-22      5.70  5.53  5.92  5.312859e+08  5.54
# 4  2020-05-21      5.54  5.53  5.75  1.249002e+08  5.66

# %%
aselsan.head()
# Out:
#          Date  adjclose    low   high         volume   open
# 0  2020-05-29     30.18  29.90  30.24   580755626.78  30.06
# 1  2020-05-28     30.06  29.86  30.46   809468165.06  30.08
# 2  2020-05-27     30.08  29.52  30.30  1020823935.08  29.28
# 3  2020-05-22     29.28  29.16  29.62   579168125.52  29.56
# 4  2020-05-21     29.56  29.46  30.02   912095587.32  29.60

# %%
bimas.head()
# Out:
#          Date  adjclose    low   high        volume  open
# 0  2020-05-29      65.1  61.40  65.10  4.344009e+08  61.7
# 1  2020-05-28      61.7  61.40  63.25  1.656471e+08  62.8
# 2  2020-05-27      62.8  62.20  65.00  2.653194e+08  63.2
# 3  2020-05-22      63.2  61.45  64.30  2.498954e+08  61.9
# 4  2020-05-21      61.9  60.10  62.60  2.385007e+08  60.0

# %%
ulker.head()
# Out:
#          Date  adjclose    low   high       volume   open
# 0  2020-05-29     23.60  23.60  24.12  48310601.82  23.98
# 1  2020-05-28     23.98  23.84  24.50  52315631.48  23.78
# 2  2020-05-27     23.78  23.64  24.02  36316795.02  23.66
# 3  2020-05-22     23.66  23.42  24.06  21864517.16  23.90
# 4  2020-05-21     23.90  23.58  24.18  30558655.04  23.96

# %%
vestel.head()
# Out:
#          Date  adjclose    low   high        volume   open
# 0  2020-05-29     14.17  13.52  14.28  1.352480e+08  13.79
# 1  2020-05-28     13.79  13.65  14.01  5.929042e+07  13.84
# 2  2020-05-27     13.84  13.71  14.03  1.142331e+08  13.62
# 3  2020-05-22     13.62  13.50  13.94  9.635632e+07  13.82
# 4  2020-05-21     13.82  13.35  14.12  2.837608e+08  13.30

# %%
enerjisa.head()
# Out:
#          Date  adjclose   low  high       volume  open
# 0  2020-05-29      8.12  7.82  8.12  38565946.40  7.90
# 1  2020-05-28      7.90  7.82  8.15  37654750.45  8.09
# 2  2020-05-27      8.09  8.03  8.24  51000462.49  8.05
# 3  2020-05-22      8.05  7.87  8.08  30812417.40  7.96
# 4  2020-05-21      7.96  7.90  8.15  52301190.45  7.89

# %%
ford.head()
# Out:
#          Date  adjclose    low   high       volume   open
# 0  2020-05-29     61.85  61.65  64.35  54522768.85  64.05
# 1  2020-05-28     64.05  64.00  69.00  36856444.40  63.05
# 2  2020-05-27     63.05  60.80  63.15  36532371.65  60.50
# 3  2020-05-22     60.50  58.65  60.80  17859450.55  59.95
# 4  2020-05-21     59.95  59.00  61.40  22108558.65  60.90

# %%
ttelekom.head()
# Out:
#          Date  adjclose   low  high        volume  open
# 0  2020-05-29      7.43  7.43  7.55   65431982.19  7.57
# 1  2020-05-28      7.57  7.54  7.74  114272200.67  7.68
# 2  2020-05-27      7.68  7.64  7.85  240010584.54  7.58
# 3  2020-05-22      7.58  7.52  7.62   70463021.38  7.63
# 4  2020-05-21      7.63  7.56  7.72   93400654.63  7.70

# %%
karsan.head()
# Out:
#          Date  adjclose   low  high        volume  open
# 0  2020-05-29      1.81  1.79  1.86  1.834763e+08  1.79
# 1  2020-05-28      1.79  1.78  1.84  1.028780e+08  1.81
# 2  2020-05-27      1.81  1.81  1.86  1.135659e+08  1.81
# 3  2020-05-22      1.81  1.75  1.83  1.952855e+08  1.77
# 4  2020-05-21      1.77  1.75  1.81  1.289004e+08  1.75

# %%
eczacibasi.columns
# Out:
# Index(['Date', 'adjclose', 'low', 'high', 'volume', 'open'], dtype='object')

# %%
fig = px.line(eczacibasi, x = 'Date', y = 'low', title='The lowest change over the years')
fig.show()
# Out:
# <div>                            <div id="eafcfe10-f04c-4de2-978b-abd55837469f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eafcfe10-f04c-4de2-978b-abd55837469f")) {                    Plotly.newPlot(                        "eafcfe10-f04c-4de2-978b-abd55837469f",                        [{"hovertemplate":"Date=%{x}<br>low=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2020-05-29","2020-05-28","2020-05-27","2020-05-22","2020-05-21","2020-05-20","2020-05-18","2020-05-15","2020-05-14","2020-05-13","2020-05-12","2020-05-11","2020-05-08","2020-05-07","2020-05-06","2020-05-05","2020-05-04","2020-04-30","2020-04-29","2020-04-28","2020-04-27","
# ...

# %%
fig = px.line(aselsan, x = 'Date', y = 'low', title='The lowest change over the years')
fig.show()
# Out:
# <div>                            <div id="1a14db69-5c65-4cd4-a376-498f5e74fd8c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a14db69-5c65-4cd4-a376-498f5e74fd8c")) {                    Plotly.newPlot(                        "1a14db69-5c65-4cd4-a376-498f5e74fd8c",                        [{"hovertemplate":"Date=%{x}<br>low=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2020-05-29","2020-05-28","2020-05-27","2020-05-22","2020-05-21","2020-05-20","2020-05-18","2020-05-15","2020-05-14","2020-05-13","2020-05-12","2020-05-11","2020-05-08","2020-05-07","2020-05-06","2020-05-05","2020-05-04","2020-04-30","2020-05-18","2020-05-15","2020-05-14","
# ...

# %%
fig = px.line(bimas, x = 'Date', y = 'low', title='The lowest change over the years')
fig.show()
# Out:
# <div>                            <div id="a1bf04a3-68d3-4ce0-9009-c780d9220ea5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1bf04a3-68d3-4ce0-9009-c780d9220ea5")) {                    Plotly.newPlot(                        "a1bf04a3-68d3-4ce0-9009-c780d9220ea5",                        [{"hovertemplate":"Date=%{x}<br>low=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2020-05-29","2020-05-28","2020-05-27","2020-05-22","2020-05-21","2020-05-20","2020-05-18","2020-05-15","2020-05-14","2020-05-13","2020-05-12","2020-05-11","2020-05-08","2020-05-07","2020-05-06","2020-05-05","2020-05-04","2020-04-30","2020-04-29","2020-04-28","2020-04-27","
# ...

# %%
fig = px.line(ulker, x = 'Date', y = 'high', title='The lowest change over the years')
fig.show()
# Out:
# <div>                            <div id="14534c61-de58-4e86-b5e0-f7908082eb64" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14534c61-de58-4e86-b5e0-f7908082eb64")) {                    Plotly.newPlot(                        "14534c61-de58-4e86-b5e0-f7908082eb64",                        [{"hovertemplate":"Date=%{x}<br>high=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2020-05-29","2020-05-28","2020-05-27","2020-05-22","2020-05-21","2020-05-20","2020-05-18","2020-05-15","2020-05-14","2020-05-13","2020-05-12","2020-05-11","2020-05-08","2020-05-07","2020-05-06","2020-05-05","2020-05-04","2020-04-30","2020-05-18","2020-04-29","2020-04-28",
# ...

# %%
fig = px.line(vestel, x = 'Date', y = 'high', title='The lowest change over the years')
fig.show()
# Out:
# <div>                            <div id="51eb9466-2d75-46aa-a9b6-6a1c96dd2b94" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51eb9466-2d75-46aa-a9b6-6a1c96dd2b94")) {                    Plotly.newPlot(                        "51eb9466-2d75-46aa-a9b6-6a1c96dd2b94",                        [{"hovertemplate":"Date=%{x}<br>high=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2020-05-29","2020-05-28","2020-05-27","2020-05-22","2020-05-21","2020-05-20","2020-05-18","2020-05-15","2020-05-14","2020-05-13","2020-05-12","2020-05-11","2020-05-08","2020-05-07","2020-05-06","2020-05-05","2020-05-04","2020-04-30","2020-04-29","2020-04-28","2020-04-27",
# ...

# %%
fig = px.line(enerjisa, x = 'Date', y = 'high', title='The lowest change over the years')
fig.show()
# Out:
# <div>                            <div id="4eeeff67-5f02-4527-aeed-ddf6fe32aa33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4eeeff67-5f02-4527-aeed-ddf6fe32aa33")) {                    Plotly.newPlot(                        "4eeeff67-5f02-4527-aeed-ddf6fe32aa33",                        [{"hovertemplate":"Date=%{x}<br>high=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-05-29","2020-05-28","2020-05-27","2020-05-22","2020-05-21","2020-05-20","2020-05-18","2020-05-15","2020-05-14","2020-05-13","2020-05-12","2020-05-11","2020-05-08","2020-05-07","2020-05-06","2020-05-05","2020-05-04","2020-04-30","2020-04-29","2020-04
# ...

# %%
fig = px.line(ttelekom, x = 'Date', y = 'high', title='The lowest change over the years')
fig.show()
# Out:
# <div>                            <div id="4e3a08bd-8c86-427a-bbc3-98b4dd35a879" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e3a08bd-8c86-427a-bbc3-98b4dd35a879")) {                    Plotly.newPlot(                        "4e3a08bd-8c86-427a-bbc3-98b4dd35a879",                        [{"hovertemplate":"Date=%{x}<br>high=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2020-05-29","2020-05-28","2020-05-27","2020-05-22","2020-05-21","2020-05-20","2020-05-18","2020-05-15","2020-05-14","2020-05-13","2020-05-12","2020-05-11","2020-05-08","2020-05-07","2020-05-06","2020-05-05","2020-05-04","2020-04-30","2020-05-18","2020-05-15","2020-05-14",
# ...

# %%
karsan_i = karsan.set_index('Date')
eczacibasi_i = eczacibasi.set_index('Date')
aselsan_i = aselsan.set_index('Date')
bimas_i = bimas.set_index('Date')
ttelekom_i = ttelekom.set_index('Date')
enerjisa_i = enerjisa.set_index('Date')
ulker_i = ulker.set_index('Date')
vestel_i = vestel.set_index('Date')
ford_i = ford.set_index('Date')

# %%
karsan_i['open'].plot(label = 'KARSAN Open price', figsize= (16,8))
eczacibasi_i['open'].plot(label = 'ECZACİBASİ Open price', figsize= (16,8))
aselsan_i['open'].plot(label = 'ASELSAN Open price', figsize= (16,8))
bimas_i['open'].plot(label = 'BİMAS Open price', figsize= (16,8))
ttelekom_i['open'].plot(label = 'TTELEKOM Open price', figsize= (16,8))
enerjisa_i['open'].plot(label = 'ENERJİSA Open price', figsize= (16,8))
ulker_i['open'].plot(label = 'ULKER Open price', figsize= (16,8))
vestel_i['open'].plot(label = 'VESTEL Open price', figsize= (16,8))
ford_i['open'].plot(label = 'FORD Open price', figsize= (16,8))
plt.legend()

# %%
karsan_i.columns
# Out:
# Index(['adjclose', 'low', 'high', 'volume', 'open'], dtype='object')

# %%
karsan_i['volume'].plot(label = 'KARSAN Volume Traded by', figsize= (16,8))
plt.show()

# %%
aselsan_i['open'].plot(label = 'ASELSAN Open price', figsize= (16,8))
plt.show()

# %%
aselsan_i['open'].plot(label = 'ASELSAN Open price', figsize= (16,8))
aselsan_i['low'].plot(label = 'ASELSAN low price')
aselsan_i['high'].plot(label = 'ASELSAN high price')
plt.legend()

# %%
bimas_i['open'].plot(label = 'ASELSAN Open price', figsize= (16,8))
bimas_i['low'].plot(label = 'ASELSAN low price')
bimas_i['high'].plot(label = 'ASELSAN high price')
plt.legend()

# %%
ttelekom_i['open'].plot(label = 'ASELSAN Open price', figsize= (16,8))
ttelekom_i['low'].plot(label = 'ASELSAN low price')
ttelekom_i['high'].plot(label = 'ASELSAN high price')
plt.legend()

# %%
aselsan_i['open'].hist(bins=100, label = 'Aselsan', alpha=0.5, figsize=(18,6))
bimas_i['open'].hist(bins=100, label = 'Bimas', alpha=0.5)
karsan_i['open'].hist(bins=100, label = 'Karsan', alpha=0.5)
ttelekom_i['open'].hist(bins=100, label = 'Ttelekom', alpha=0.5)
vestel_i['open'].hist(bins=100, label = 'Vestel', alpha=0.5)
plt.legend()

# %% [markdown]
# # Thank You...
