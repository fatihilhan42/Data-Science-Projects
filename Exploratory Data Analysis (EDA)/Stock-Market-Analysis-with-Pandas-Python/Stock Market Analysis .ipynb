# %%
import pandas_datareader.data as web 
import datetime
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
start = datetime.datetime(2021,1,1)
end = datetime.datetime(2022,2,25)

# %%
google = web.DataReader("GOOGL", "yahoo", start, end)

# %%
google.head()
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2021-01-04  1762.489990  1707.140015  1760.000000  1726.130005  1866200
# 2021-01-05  1746.829956  1716.900024  1725.089966  1740.050049  1018000
# 2021-01-06  1743.969971  1696.099976  1700.260010  1722.880005  2329400
# 2021-01-07  1777.819946  1726.760010  1726.760010  1774.339966  2096800
# 2021-01-08  1799.359985  1761.219971  1777.160034  1797.829956  1774200
#
#               Adj Close
# Date
# 2021-01-04  1726.130005
# 2021-01-05  1740.050049
# 2021-01-06  1722.880005
# 2021-01-07  1774.339966
# 2021-01-08  1797.829956

# %%
google.tail()
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2022-02-18  2681.399902  2603.929932  2669.340088  2608.060059  2277400
# 2022-02-22  2643.610107  2564.469971  2596.760010  2596.270020  2249500
# 2022-02-23  2641.020020  2550.550049  2632.969971  2551.760010  1639300
# 2022-02-24  2660.000000  2499.070068  2499.070068  2653.820068  2722800
# 2022-02-25  2705.429932  2635.030029  2671.040039  2689.189941  1818000
#
#               Adj Close
# Date
# 2022-02-18  2608.060059
# 2022-02-22  2596.270020
# 2022-02-23  2551.760010
# 2022-02-24  2653.820068
# 2022-02-25  2689.189941

# %%
google['Open'].plot(figsize = (16,8))
plt.show()

# %%
google['Open'].plot(label = 'GOOGL Open price', figsize= (16,8))
google['Close'].plot(label = 'GOOGL Close price')
google['High'].plot(label = 'GOOGL High price')
google['Low'].plot(label = 'GOOGL Low price')
plt.legend()
plt.title('Google Stock Prices')
plt.ylabel('Stock Price')
plt.show()

# %%
google['Volume'].plot(figsize = (15,7))
plt.title('Volume Traded by Google')
# Out:
# Text(0.5, 1.0, 'Volume Traded by Google')

# %%
tesla = web.DataReader("TSLA",'yahoo', start, end)
ford  = web.DataReader("F", 'yahoo', start, end)
gm = web.DataReader("GM", 'yahoo', start,end)

# %%
tesla.to_csv('Tesla_Stock.csv')
ford.to_csv('Ford_Stock.csv')
gm.to_csv('GM_Stock.csv')

# %%
tesla.head()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2021-01-04  744.489990  717.190002  719.460022  729.770020  48638200
# 2021-01-05  740.840027  719.200012  723.659973  735.109985  32245200
# 2021-01-06  774.000000  749.099976  758.489990  755.979980  44700000
# 2021-01-07  816.989990  775.200012  777.630005  816.039978  51498900
# 2021-01-08  884.489990  838.390015  856.000000  880.020020  75055500
#
#              Adj Close
# Date
# 2021-01-04  729.770020
# 2021-01-05  735.109985
# 2021-01-06  755.979980
# 2021-01-07  816.039978
# 2021-01-08  880.020020

# %%
tesla.tail()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2022-02-18  886.869995  837.609985  886.000000  856.979980  22710500
# 2022-02-22  856.729980  801.099976  834.130005  821.530029  27762700
# 2022-02-23  835.299988  760.559998  830.429993  764.039978  31752300
# 2022-02-24  802.479980  700.000000  700.390015  800.770020  45107400
# 2022-02-25  819.500000  782.400024  809.229980  809.869995  25309500
#
#              Adj Close
# Date
# 2022-02-18  856.979980
# 2022-02-22  821.530029
# 2022-02-23  764.039978
# 2022-02-24  800.770020
# 2022-02-25  809.869995

# %%
gm.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2021-01-04  42.119999  40.139999  41.950001  40.509998  15768100  40.509998
# 2021-01-05  41.840000  40.040001  40.060001  41.660000  18045800  41.660000
# 2021-01-06  43.849998  41.860001  41.919998  42.980000  22694900  42.980000
# 2021-01-07  43.980000  42.959999  43.980000  43.320000  13625700  43.320000
# 2021-01-08  43.490002  42.320000  43.310001  43.060001  18426200  43.060001

# %%
gm.tail()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2022-02-18  49.209999  47.919998  48.919998  48.599998  16606400  48.599998
# 2022-02-22  47.939999  46.160000  47.779999  46.770000  19620300  46.770000
# 2022-02-23  48.299999  46.259998  47.259998  46.380001  13667700  46.380001
# 2022-02-24  46.410000  43.910000  44.150002  46.349998  21003700  46.349998
# 2022-02-25  47.480000  45.849998  46.349998  47.430000  13458800  47.430000

# %%
ford.head()
# Out:
#             High   Low  Open  Close      Volume  Adj Close
# Date
# 2021-01-04  8.84  8.43  8.81   8.52  85043100.0   8.433952
# 2021-01-05  8.72  8.46  8.47   8.65  70127800.0   8.562639
# 2021-01-06  8.94  8.68  8.79   8.84  72590200.0   8.750721
# 2021-01-07  9.08  8.88  8.94   9.06  77117100.0   8.968499
# 2021-01-08  9.14  8.89  9.10   9.00  59162200.0   8.909104

# %%
ford.tail()
# Out:
#                  High        Low   Open      Close       Volume  Adj Close
# Date
# 2022-02-18  18.480000  17.570000  17.60  18.040001  106204100.0  18.040001
# 2022-02-22  17.760000  17.070000  17.67  17.290001   98550700.0  17.290001
# 2022-02-23  17.730000  16.879999  17.50  16.950001   79855400.0  16.950001
# 2022-02-24  17.190001  15.960000  15.99  17.150000  110443900.0  17.150000
# 2022-02-25  17.900000  17.120001  17.25  17.830000   78772400.0  17.830000

# %%
tesla['Open'].plot(label = 'Tesla', figsize= (16,8))
gm['Open'].plot(label = 'GM')
ford['Open'].plot(label = 'Ford')
plt.legend()
plt.title('Stock Prices of Tesla, GM, Ford')
plt.ylabel('Stock Price')
plt.show()

# %%
tesla['Volume'].plot(label = 'Tesla', figsize= (16,8))
gm['Volume'].plot(label = 'GM')
ford['Volume'].plot(label = 'Ford')
plt.legend()
plt.ylabel('Volume Traded')
# Out:
# Text(0, 0.5, 'Volume Traded')

# %%
ford.iloc[[ford['Volume'].argmax()]]
# Out:
#                  High    Low   Open      Close       Volume  Adj Close
# Date
# 2022-01-04  24.559999  22.42  22.52  24.309999  311645200.0  24.185652

# %%
tesla['Total Traded']= tesla['Open'] * tesla['Volume']
gm['Total Traded']= gm['Open'] * gm['Volume']
ford['Total Traded']= ford['Open'] * ford['Volume']

# %%
tesla['Total Traded'].plot(label = 'Tesla', figsize= (16,8))
gm['Total Traded'].plot(label = 'GM')
ford['Total Traded'].plot(label = 'Ford')
plt.legend()
plt.ylabel('Total Traded')
# Out:
# Text(0, 0.5, 'Total Traded')

# %%
tesla['Total Traded'].argmax()
# Out:
# 215

# %%
tesla.iloc[[tesla['Total Traded'].argmax()]]
# Out:
#               High         Low         Open   Close    Volume  Adj Close  \
# Date
# 2021-11-09  1174.5  1011.52002  1173.599976  1023.5  59105800     1023.5
#
#             Total Traded
# Date
# 2021-11-09  6.936657e+10

# %%
gm['Open'].iloc[100:200].plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
gm['Open'].plot(label = 'No Moving Average', figsize= (16,8))
gm['MA50']=gm['Open'].rolling(50).mean()
gm['MA50'].plot(label='MA50')
gm['MA200']= gm['Open'].rolling(200).mean()
gm['MA200'].plot(label='MA200')
plt.legend()

# %%
tesla['Open'].plot(label = 'No Moving Average', figsize= (16,8))
tesla['MA50']=tesla['Open'].rolling(50).mean()
tesla['MA50'].plot(label='MA50')
tesla['MA200']= tesla['Open'].rolling(200).mean()
tesla['MA200'].plot(label='MA200')
plt.legend()

# %%
ford['Open'].plot(label = 'No Moving Average', figsize= (16,8))
ford['MA50']=ford['Open'].rolling(50).mean()
ford['MA50'].plot(label='MA50')
ford['MA200']= ford['Open'].rolling(200).mean()
ford['MA200'].plot(label='MA200')
plt.legend()

# %%
from pandas.plotting import scatter_matrix
import pandas as pd

# %%
car_comp = pd.concat([tesla['Open'],gm['Open'],ford['Open']],axis = 1)
car_comp.columns = ['Tesla Open', 'GM Open', 'Ford Open']

# %%
scatter_matrix(car_comp,figsize = (12,12))
# Out:
# array([[<AxesSubplot:xlabel='Tesla Open', ylabel='Tesla Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='Tesla Open'>,
#         <AxesSubplot:xlabel='Ford Open', ylabel='Tesla Open'>],
#        [<AxesSubplot:xlabel='Tesla Open', ylabel='GM Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='GM Open'>,
#         <AxesSubplot:xlabel='Ford Open', ylabel='GM Open'>],
#        [<AxesSubplot:xlabel='Tesla Open', ylabel='Ford Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='Ford Open'>,
#         <AxesSubplot:xlabel='Ford Open', ylabel='Ford Open'>]],
#       dtype=object)

# %%
from mpl_finance import candlestick_ohlc
from matplotlib.dates import DateFormatter, date2num , WeekdayLocator, DayLocator, MONDAY

ford_reset = ford.loc['2022-01' : '2022-01'].reset_index()

ford_reset['date_ax']  = ford_reset['Date'].apply(lambda date: date2num(date))
ford_values = [tuple(vals) for vals in ford_reset[['date_ax', 'Open', 'High', 'Low', 'Close']].values]

mondays = WeekdayLocator(MONDAY)
alldays = DayLocator()
weekFormatter = DateFormatter('%b %d')
dayFormatter = DateFormatter('%d')

fig, ax = plt.subplots()
candlestick_ohlc(ax,ford_values,width = 0.6, colorup='g',colordown='r')
# Out:
# ([<matplotlib.lines.Line2D at 0x1516df35be0>,
# ...
#   <matplotlib.patches.Rectangle at 0x1516dfc4e80>])

# %% [markdown]
#     $ r_{t} = (\frac p_{t})$ formül yaz

# %%
tesla['returns'] = (tesla['Close']/tesla['Close'].shift(1)) - 1

# %%
tesla.head()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2021-01-04  744.489990  717.190002  719.460022  729.770020  48638200
# 2021-01-05  740.840027  719.200012  723.659973  735.109985  32245200
# 2021-01-06  774.000000  749.099976  758.489990  755.979980  44700000
# 2021-01-07  816.989990  775.200012  777.630005  816.039978  51498900
# 2021-01-08  884.489990  838.390015  856.000000  880.020020  75055500
#
#              Adj Close  Total Traded  MA50  MA200   returns
# Date
# 2021-01-04  729.770020  3.499324e+10   NaN    NaN       NaN
# 2021-01-05  735.109985  2.333456e+10   NaN    NaN  0.007317
# 2021-01-06  755.979980  3.390450e+10   NaN    NaN  0.028390
# 2021-01-07  816.039978  4.004709e+10   NaN    NaN  0.079447
# 2021-01-08  880.020020  6.424751e+10   NaN    NaN  0.078403

# %%
ford['returns']  = (ford['Close'] / ford['Close'].shift(1)) - 1
gm['returns']  = (gm['Close'] / gm['Close'].shift(1)) - 1

# %%
ford.head()
# Out:
#             High   Low  Open  Close      Volume  Adj Close  Total Traded  \
# Date
# 2021-01-04  8.84  8.43  8.81   8.52  85043100.0   8.433952  7.492297e+08
# 2021-01-05  8.72  8.46  8.47   8.65  70127800.0   8.562639  5.939825e+08
# 2021-01-06  8.94  8.68  8.79   8.84  72590200.0   8.750721  6.380679e+08
# 2021-01-07  9.08  8.88  8.94   9.06  77117100.0   8.968499  6.894268e+08
# 2021-01-08  9.14  8.89  9.10   9.00  59162200.0   8.909104  5.383760e+08
#
#             MA50  MA200   returns
# Date
# 2021-01-04   NaN    NaN       NaN
# 2021-01-05   NaN    NaN  0.015258
# 2021-01-06   NaN    NaN  0.021965
# 2021-01-07   NaN    NaN  0.024887
# 2021-01-08   NaN    NaN -0.006623

# %%
gm.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close  \
# Date
# 2021-01-04  42.119999  40.139999  41.950001  40.509998  15768100  40.509998
# 2021-01-05  41.840000  40.040001  40.060001  41.660000  18045800  41.660000
# 2021-01-06  43.849998  41.860001  41.919998  42.980000  22694900  42.980000
# 2021-01-07  43.980000  42.959999  43.980000  43.320000  13625700  43.320000
# 2021-01-08  43.490002  42.320000  43.310001  43.060001  18426200  43.060001
#
#             Total Traded  MA50  MA200   returns
# Date
# 2021-01-04  6.614718e+08   NaN    NaN       NaN
# 2021-01-05  7.229148e+08   NaN    NaN  0.028388
# 2021-01-06  9.513702e+08   NaN    NaN  0.031685
# 2021-01-07  5.992583e+08   NaN    NaN  0.007911
# 2021-01-08  7.980387e+08   NaN    NaN -0.006002

# %%
ford['returns'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
tesla['returns'].hist(bins=100, label = 'Tesla', alpha=0.5, figsize=(18,6))
gm['returns'].hist(bins=100, label = 'GM', alpha=0.5)
ford['returns'].hist(bins=100, label = 'Ford', alpha=0.5)
plt.legend()

# %%
tesla['returns'].plot(kind='kde', label='Tesla')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
tesla['returns'].plot(kind='kde', label='Tesla')
ford['returns'].plot(kind='kde', label='Ford')
gm['returns'].plot(kind='kde', label='GM')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
box_df = pd.concat([tesla['returns'], gm['returns'], ford['returns']], axis = 1)
box_df.columns = ['Tesla Returns', 'GM Returns', 'Ford Returns']
box_df.plot(kind = 'box', figsize=(15,6))
# Out:
# <AxesSubplot:>

# %%
scatter_matrix(box_df, figsize=(18,8), hist_kwds={'bins' : 50}, alpha = 0.25)
# Out:
# array([[<AxesSubplot:xlabel='Tesla Returns', ylabel='Tesla Returns'>,
#         <AxesSubplot:xlabel='GM Returns', ylabel='Tesla Returns'>,
#         <AxesSubplot:xlabel='Ford Returns', ylabel='Tesla Returns'>],
#        [<AxesSubplot:xlabel='Tesla Returns', ylabel='GM Returns'>,
#         <AxesSubplot:xlabel='GM Returns', ylabel='GM Returns'>,
#         <AxesSubplot:xlabel='Ford Returns', ylabel='GM Returns'>],
#        [<AxesSubplot:xlabel='Tesla Returns', ylabel='Ford Returns'>,
#         <AxesSubplot:xlabel='GM Returns', ylabel='Ford Returns'>,
#         <AxesSubplot:xlabel='Ford Returns', ylabel='Ford Returns'>]],
#       dtype=object)

# %%
tesla['Cumulative Return'] = (1 + tesla['returns']).cumprod()
ford['Cumulative Return'] = (1 + ford['returns']).cumprod()
gm['Cumulative Return'] = (1 + gm['returns']).cumprod()

# %%
tesla['Cumulative Return'].plot(label='Tesla',figsize = (16,8))
ford['Cumulative Return'].plot(label='Ford')
gm['Cumulative Return'].plot(label='GM')
plt.title('Cumulative Return vs Time')
plt.legend()
